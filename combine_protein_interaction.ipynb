# %%
import pandas as pd

# %%
## reading train.csv
raw_train = pd.read_csv("./train.csv", header=None, 
                        keep_default_na=True, na_values='?',
                        na_filter=True)

# %%
# 862 x 2961
raw_rows, raw_columns = raw_train.shape

# %%
# 460th to 2954th columns are encoded in protein_interactions.csv
protein_interactions_cols = list(range(459, 2954))
# reduced down to 466 columns
reduced_train = raw_train.drop(raw_train.columns[protein_interactions_cols], axis = 1)
reduced_train = reduced_train.T.reset_index(drop=True).T

cleaned_train = reduced_train
cleaned_rows, cleaned_columns = cleaned_train.shape

# %%
# renaming some columns
cleaned_train = cleaned_train.rename({0 : "protein",
                      1 : "essential",
                      444 : "chromosome",
                      cleaned_columns - 1 : "label",
                      cleaned_columns - 2 : "localization"},
                      axis = 1)

# %%
# Study potential relationship in protein_interactions
protein_interactions = pd.read_csv('./protein_interactions.csv', header=None, na_values = '?.',
                                   names = ('protein1', 'protein2', 'type', 'correlation'),
                                  dtype = {'correlation' : str})

# %%
protein_interactions['correlation']
# Out:
# 0       0.252653076.
# 1       0.709247942.
# 2      -0.001238791.
# 3       0.482255315.
# 4      -0.460856268.
#            ...
# 905     0.519144658.
# 906      0.21693664.
# 907    -0.128716897.
# 908     0.743719262.
# 909     -0.21443642.
# Name: correlation, Length: 910, dtype: object

# %%
# Trim the dot at the end of correlation and convert it to float
protein_interactions['correlation'] = protein_interactions['correlation'].apply(
                            lambda x : float(x[:-1]) 
                                       if str(x)[-1] == '.' 
                                        else float(x))

# %%
# protein1, protein2 interaction is not communitive
display(protein_interactions.loc[protein_interactions.protein1 == "P239467"])
display(protein_interactions.loc[protein_interactions.protein2 == "P239467"])
# Out:
#     protein1 protein2      type  correlation
# 110  P239467  P238704  Physical     0.723051
# 739  P239467  P235639  Physical    -0.483302
# 780  P239467  P235701   Genetic    -0.430352
#   protein1 protein2      type  correlation
# 0  P238510  P239467   Genetic     0.252653
# 1  P235550  P239467  Physical     0.709248
# 2  P235621  P239467  Physical    -0.001239
# 3  P235265  P239467  Physical     0.482255

# %%
# Next: incorporate the protein_interaction relation back to the dataframe

# %%
# join protein_interactions with cleaned_train
pro1_train = pd.merge(cleaned_train, protein_interactions, left_on = 'protein', right_on = 'protein1', how='left')

# %%
pro2_cleaned_train = cleaned_train[['protein', 'essential', 'chromosome', 'localization', 'label']]

# %%
protein_train = pd.merge(pro1_train, pro2_cleaned_train, 
                         left_on = 'protein2', right_on = 'protein', how = 'left',
                         suffixes = ['', '_interact'])

# %%
# change correlation to categorical variable
def correlation_classifer(cor):
    cor = float(cor)
    if (pd.isna(cor)):
        return "Missing"
    if (cor >= 0):
        if (cor >= 0.5):
            return "Strong Positive"
        else:
            return "Weak Positive"
    else:
        if (cor <= -0.5):
            return "Strong Negative"
        else:
            return "Weak Negative"
protein_train["correlation"] = protein_train["correlation"].apply(correlation_classifer)

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.preprocessing import LabelEncoder
XY_train = protein_train.drop(["protein", "protein1", "protein2", "protein_interact"], axis=1)
XY_train = XY_train.apply(LabelEncoder().fit_transform)
X_train = XY_train.drop(['label'], axis = 1)
Y_train = XY_train.label
# define feature selection
fs = SelectKBest(score_func=chi2, k='all')
# apply feature selection
X_selected = fs.fit_transform(X_train, Y_train)
print(X_selected.shape)
# Out:
# (1312, 470)

# %%
for i in range(len(fs.scores_)):
    print('Feature %d: %f' % (i, fs.scores_[i]))
# Out:
# Feature 0: 12.540962
# Feature 1: 53.053097
# Feature 2: nan
# Feature 3: 68.052632
# Feature 4: 39.511286
# Feature 5: 39.111111
# Feature 6: nan
# Feature 7: 68.981064
# Feature 8: 7.111111
# Feature 9: 105.512645
# Feature 10: 18.896000
# Feature 11: 13.627986
# Feature 12: nan
# Feature 13: 45.924766
# Feature 14: 61.926690
# Feature 15: 1.238908
# Feature 16: 18.896000
# Feature 17: nan
# Feature 18: 34.580312
# Feature 19: 14.189606
# Feature 20: 15.630146
# Feature 21: 30.617678
# Feature 22: 77.393049
# Feature 23: 42.442478
# Feature 24: 10.570682
# Feature 25: 16.972603
# Feature 26: 16.972603
# Feature 27: 21.333333
# Feature 28: 8.672355
# Feature 29: 7.111111
# Feature 30: 3.555556
# Feature 31: 96.819109
# Feature 32: 14.222222
# Feature 33: 17.777778
# Feature 34: 17.615300
# Feature 35: nan
# Feature 36: 17.777778
# Feature 37: 24.136317
# Feature 38: 519.029592
# Feature 39: 86.466667
# Feature 40: 16.972603
# Feature 41: 35.555556
# Feature 42: 3.555556
# Feature 43: 42.666667
# Feature 44: 47.870381
# Feature 45: nan
# Feature 46: 280.217391
# Feature 47: nan
# Feature 48: 64.600573
# Feature 49: 3.716724
# Feature 50: 532.902271
# Feature 51: nan
# Feature 52: 17.777778
# Feature 53: 7.433447
# Feature 54: 3.555556
# Feature 55: 237.616438
# Feature 56: 3.716724
# Feature 57: 7.111111
# Feature 58: 29.346542
# Feature 59: 11.150171
# Feature 60: nan
# Feature 61: 3.555556
# Feature 62: 14.222222
# Feature 63: 33.945205
# Feature 64: 18.583618
# Feature 65: 16.972603
# Feature 66: 3.555556
# Feature 67: 47.078498
# Feature 68: 186.698630
# Feature 69: 1.397232
# Feature 70: 71.786015
# Feature 71: 9.911263
# Feature 72: 10.610619
# Feature 73: 6.809727
# Feature 74: 1.238908
# Feature 75: nan
# Feature 76: 16.972603
# Feature 77: 2.477816
# Feature 78: 232.189157
# Feature 79: 204.504633
# Feature 80: 187.255556
# Feature 81: 165.472226
# Feature 82: 111.785866
# Feature 83: 96.809030
# Feature 84: 267.101192
# Feature 85: 36.777553
# Feature 86: 49.704544
# Feature 87: 102.692911
# Feature 88: 19.400836
# Feature 89: 18.182779
# Feature 90: 49.751068
# Feature 91: 144.336915
# Feature 92: 11.496812
# Feature 93: 102.697316
# Feature 94: 164.022430
# Feature 95: 20.972193
# Feature 96: 70.394805
# Feature 97: 10.610619
# Feature 98: 10.610619
# Feature 99: 23.754717
# Feature 100: 1.238908
# Feature 101: 11.150171
# Feature 102: 11.750803
# Feature 103: 2.176432
# Feature 104: 1.238908
# Feature 105: 3.716724
# Feature 106: 9.767849
# Feature 107: 23.754717
# Feature 108: 2.477816
# Feature 109: 3.716724
# Feature 110: 3.555556
# Feature 111: 3.555556
# Feature 112: nan
# Feature 113: nan
# Feature 114: 7.111111
# Feature 115: 1.238908
# Feature 116: 7.111111
# Feature 117: nan
# Feature 118: 10.666667
# Feature 119: nan
# Feature 120: 3.716724
# Feature 121: nan
# Feature 122: 3.555556
# Feature 123: 3.555556
# Feature 124: nan
# Feature 125: nan
# Feature 126: nan
# Feature 127: 3.555556
# Feature 128: nan
# Feature 129: nan
# Feature 130: 3.555556
# Feature 131: 86.466667
# Feature 132: nan
# Feature 133: nan
# Feature 134: 16.972603
# Feature 135: nan
# Feature 136: 14.735775
# Feature 137: 13.379436
# Feature 138: 3.555556
# Feature 139: nan
# Feature 140: 1.238908
# Feature 141: nan
# Feature 142: nan
# Feature 143: 1.238908
# Feature 144: 10.666667
# Feature 145: 3.555556
# Feature 146: 23.296296
# Feature 147: 14.244421
# Feature 148: 16.263158
# Feature 149: 16.263158
# Feature 150: 7.226222
# Feature 151: nan
# Feature 152: nan
# Feature 153: 7.111111
# Feature 154: 7.111111
# Feature 155: 11.032322
# Feature 156: nan
# Feature 157: nan
# Feature 158: nan
# Feature 159: nan
# Feature 160: 3.555556
# Feature 161: 3.555556
# Feature 162: 3.555556
# Feature 163: 23.296296
# Feature 164: nan
# Feature 165: nan
# Feature 166: 1.238908
# Feature 167: 1.238908
# Feature 168: 16.972603
# Feature 169: 1.238908
# Feature 170: nan
# Feature 171: 3.555556
# Feature 172: 12.425926
# Feature 173: 16.972603
# Feature 174: 7.034514
# Feature 175: 23.296296
# Feature 176: 46.592593
# Feature 177: 16.972603
# Feature 178: 16.972603
# Feature 179: 16.972603
# Feature 180: 16.972603
# Feature 181: 31.524808
# Feature 182: 9.064942
# Feature 183: 16.972603
# Feature 184: 71.264151
# Feature 185: 95.018868
# Feature 186: 47.509434
# Feature 187: nan
# Feature 188: 27.967680
# Feature 189: 42.442478
# Feature 190: 10.610619
# Feature 191: 21.221239
# Feature 192: nan
# Feature 193: 1.238908
# Feature 194: 7.111111
# Feature 195: 1.238908
# Feature 196: 29.062081
# Feature 197: nan
# Feature 198: 22.481989
# Feature 199: 7.111111
# Feature 200: nan
# Feature 201: 23.296296
# Feature 202: 10.666667
# Feature 203: nan
# Feature 204: 1.238908
# Feature 205: 1.238908
# Feature 206: nan
# Feature 207: nan
# Feature 208: 21.185566
# Feature 209: 3.555556
# Feature 210: 2.477816
# Feature 211: 1.238908
# Feature 212: 1.238908
# Feature 213: 1.238908
# Feature 214: 8.615245
# Feature 215: 4.955631
# Feature 216: 1.238908
# Feature 217: 4.955631
# Feature 218: 1.238908
# Feature 219: 1.397232
# Feature 220: 3.555556
# Feature 221: 3.555556
# Feature 222: nan
# Feature 223: 3.555556
# Feature 224: 8.105755
# Feature 225: 2.477816
# Feature 226: 16.972603
# Feature 227: 1.238908
# Feature 228: 16.972603
# Feature 229: 2.477816
# Feature 230: nan
# Feature 231: 15.617880
# Feature 232: 10.610619
# Feature 233: 63.663717
# Feature 234: 136.105263
# Feature 235: nan
# Feature 236: 4.955631
# Feature 237: nan
# Feature 238: 3.555556
# Feature 239: 1.238908
# Feature 240: nan
# Feature 241: 3.555556
# Feature 242: 7.111111
# Feature 243: 16.972603
# Feature 244: nan
# Feature 245: 1.238908
# Feature 246: nan
# Feature 247: 3.555556
# Feature 248: 3.555556
# Feature 249: 86.466667
# Feature 250: nan
# Feature 251: 8.672355
# Feature 252: 1.238908
# Feature 253: 3.555556
# Feature 254: 3.555556
# Feature 255: nan
# Feature 256: 17.777778
# Feature 257: nan
# Feature 258: nan
# Feature 259: 1.238908
# Feature 260: nan
# Feature 261: nan
# Feature 262: nan
# Feature 263: 16.972603
# Feature 264: 47.509434
# Feature 265: 86.466667
# Feature 266: 3.716724
# Feature 267: 3.555556
# Feature 268: 3.555556
# Feature 269: 1.238908
# Feature 270: nan
# Feature 271: 3.555556
# Feature 272: 3.555556
# Feature 273: 3.716724
# Feature 274: nan
# Feature 275: nan
# Feature 276: 3.555556
# Feature 277: nan
# Feature 278: 16.972603
# Feature 279: nan
# Feature 280: 3.555556
# Feature 281: 3.555556
# Feature 282: nan
# Feature 283: nan
# Feature 284: nan
# Feature 285: 2.477816
# Feature 286: 3.555556
# Feature 287: 27.255973
# Feature 288: 46.592593
# Feature 289: 23.296296
# Feature 290: 3.555556
# Feature 291: nan
# Feature 292: nan
# Feature 293: nan
# Feature 294: nan
# Feature 295: 5.255689
# Feature 296: 19.008937
# Feature 297: 8.949564
# Feature 298: nan
# Feature 299: 16.972603
# Feature 300: 2.477816
# Feature 301: 3.716724
# Feature 302: nan
# Feature 303: 2.477816
# Feature 304: 2.477816
# Feature 305: 3.555556
# Feature 306: 213.792453
# Feature 307: 16.972603
# Feature 308: nan
# Feature 309: 7.111111
# Feature 310: nan
# Feature 311: nan
# Feature 312: 86.466667
# Feature 313: 14.222222
# Feature 314: 10.610619
# Feature 315: 10.610619
# Feature 316: 10.666667
# Feature 317: 7.111111
# Feature 318: 1.238908
# Feature 319: 1.238908
# Feature 320: nan
# Feature 321: nan
# Feature 322: nan
# Feature 323: nan
# Feature 324: nan
# Feature 325: 3.555556
# Feature 326: 3.716724
# Feature 327: 3.555556
# Feature 328: nan
# Feature 329: nan
# Feature 330: 3.555556
# Feature 331: 3.555556
# Feature 332: 7.111111
# Feature 333: 16.972603
# Feature 334: 16.972603
# Feature 335: 16.972603
# Feature 336: 16.972603
# Feature 337: 7.111111
# Feature 338: 7.111111
# Feature 339: 1.238908
# Feature 340: 1.238908
# Feature 341: 5.263886
# Feature 342: 6.194539
# Feature 343: 4.955631
# Feature 344: nan
# Feature 345: nan
# Feature 346: nan
# Feature 347: 12.425926
# Feature 348: 21.035848
# Feature 349: 3.555556
# Feature 350: nan
# Feature 351: nan
# Feature 352: 3.555556
# Feature 353: 3.555556
# Feature 354: nan
# Feature 355: nan
# Feature 356: nan
# Feature 357: 9.064942
# Feature 358: nan
# Feature 359: nan
# Feature 360: 168.130435
# Feature 361: 1.397232
# Feature 362: 1.238908
# Feature 363: nan
# Feature 364: nan
# Feature 365: nan
# Feature 366: 1311.000000
# Feature 367: 3.555556
# Feature 368: nan
# Feature 369: nan
# Feature 370: nan
# Feature 371: nan
# Feature 372: 3.555556
# Feature 373: 3.555556
# Feature 374: 9.264079
# Feature 375: 2.477816
# Feature 376: 7.111111
# Feature 377: nan
# Feature 378: 3.555556
# Feature 379: 3.555556
# Feature 380: 3.555556
# Feature 381: 68.052632
# Feature 382: 68.052632
# Feature 383: 68.052632
# Feature 384: 3.555556
# Feature 385: nan
# Feature 386: nan
# Feature 387: 16.972603
# Feature 388: 16.972603
# Feature 389: nan
# Feature 390: nan
# Feature 391: nan
# Feature 392: nan
# Feature 393: 68.052632
# Feature 394: 3.555556
# Feature 395: nan
# Feature 396: nan
# Feature 397: 1.238908
# Feature 398: nan
# Feature 399: 23.296296
# Feature 400: nan
# Feature 401: nan
# Feature 402: nan
# Feature 403: 23.296296
# Feature 404: nan
# Feature 405: 3.555556
# Feature 406: 1.238908
# Feature 407: 10.610619
# Feature 408: 10.610619
# Feature 409: 8.672355
# Feature 410: nan
# Feature 411: 3.555556
# Feature 412: 2.477816
# Feature 413: 53.053097
# Feature 414: nan
# Feature 415: 7.111111
# Feature 416: 33.945205
# Feature 417: 2.477816
# Feature 418: 1.238908
# Feature 419: 1.238908
# Feature 420: 3.555556
# Feature 421: 1.397232
# Feature 422: nan
# Feature 423: nan
# Feature 424: 23.754717
# Feature 425: 23.296296
# Feature 426: 3.555556
# Feature 427: nan
# Feature 428: 1.238908
# Feature 429: 16.972603
# Feature 430: nan
# Feature 431: nan
# Feature 432: nan
# Feature 433: nan
# Feature 434: nan
# Feature 435: nan
# Feature 436: nan
# Feature 437: 23.754717
# Feature 438: 1.238908
# Feature 439: nan
# Feature 440: 3.555556
# Feature 441: nan
# Feature 442: nan
# Feature 443: 70.110861
# Feature 444: 575.894324
# Feature 445: 200.164571
# Feature 446: 86.481249
# Feature 447: 331.246693
# Feature 448: 478.933041
# Feature 449: 1638.066997
# Feature 450: 41.773555
# Feature 451: 111.527855
# Feature 452: 150.345940
# Feature 453: 147.569511
# Feature 454: 155.303489
# Feature 455: 1097.077515
# Feature 456: 168.372078
# Feature 457: nan
# Feature 458: 173.984991
# Feature 459: 211.463693
# Feature 460: 363.751486
# Feature 461: 253.336974
# Feature 462: nan
# Feature 463: 2921.419618
# Feature 464: 35.529204
# Feature 465: 66.158456
# Feature 466: 15.673804
# Feature 467: 120.779210
# Feature 468: 268.294078
# Feature 469: 606.142383
